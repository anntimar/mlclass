# %% [markdown]
# # Epithelial Map Clustering
# Análise exploratória inicial dos mapas epiteliais.

# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path('..')
DATA_PATH = BASE_DIR / 'data' / 'raw' / 'RTVue_20221110_MLClass.xlsx'
df = pd.read_excel(DATA_PATH)
df.head()

# %%
df.shape, df.columns.tolist()

# %%
features = ['C', 'S', 'ST', 'T', 'IT', 'I', 'IN', 'N', 'SN']
df[features].describe().T
